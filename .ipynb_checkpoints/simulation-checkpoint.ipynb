# %% [markdown]
# # Endüstriyel Mobil Kablosuz Ağların Optimum Kapsama Alanı için Anahtar Düğümlerin Verimli Dağıtımı

# %% [markdown]
# Endüstriyel mobil kablosuz ağlar, fabrikalar, depolar ve benzeri işletmelerde kablosuz haberleşme için kullanılan ağlardır. Bu ağların optimum kapsama alanını sağlamak için anahtar düğümlerin doğru bir şekilde dağıtılması önemlidir.
# Anahtar düğümler, ağda haberleşme için kullanılan cihazlardır ve bu cihazların optimum bir şekilde dağıtılması, ağın kapsama alanının artırılmasını ve daha iyi bir performans sağlanmasını mümkün kılar. Anahtar düğümlerin dağılımı, ağın büyüklüğüne, coğrafi koşullarına ve diğer faktörlere göre değişebilir.

# %% [markdown]
# # Gerekli kütüphaneleri import edilmesi

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Endüstriyel mobil kablosuz ağların kapsama alanını optimize etmek için Monte Carlo yöntemini kullanılabilir.
# Bu yöntem, birçok rastgele koordinat üreterek, düğümleri bu koordinatlara dağıtarak kapsama alanını en iyi şekilde elde etmeyi amaçlar.
# Numpy, rastgele koordinat üretmek ve düğümleri bu koordinatlara dağıtmak için kullanılabilir.

# %%
class Node:
  def __init__(self, coord, range=1):
    self.coord = coord
    self.range = range
# Monte Carlo yöntemini kullanarak rastgele koordinatlar üret
coords = np.random.random((100, 2))

# Düğümleri bu koordinatlara dağıt
nodes = [Node(coord) for coord in coords]

# %% [markdown]
# Öncelikle metodun giriş parametresi olarak verilen düğümlerin koordinatlarını bir diziye alır.
# Daha sonra bu koordinatları kullanarak bir scatter plot oluşturur. Scatter plot, koordinatları nokta olarak gösteren bir grafik türüdür ve matplotlib kütüphanesinde yer alır.

# %%
def calculate_coverage(nodes):
  coords = [node.coord for node in nodes]  
  plt.scatter(coords[0], coords[1]) 
  #scatter plot üzerinde, düğümlerin birbirlerine olan mesafelerini hesaplayarak çemberler çizilir. 
  #Her düğüm için bir çember çizilerek, düğümlerin kapsama alanı belirlenebilir

  for node in nodes:
    circle = plt.Circle(node.coord, node.range, color='r', fill=False)
    plt.gca().add_artist(circle)
  #scatter plot üzerinde, düğümlerin kapsama alanlarının birleşimini hesaplayarak bir poligon oluşturulur.
  # Bu poligon, düğümlerin oluşturduğu kapsama alanını gösterir
  x, y = zip(*coords)
  plt.fill(x, y, color='r', alpha=0.5)

# %%
coverage = calculate_coverage(nodes)

# %%
# Sonuçları grafik olarak görselleştir
plt.scatter(coords[:, 0], coords[:, 1], c=coverage)
plt.show()

# %% [markdown]
# Bu proje, rastgele 100 adet koordinat üretir, bu koordinatlara düğümler dağıtır ve sonuçları grafik olarak görselleştirir.

# %% [markdown]
# #### DTSMC

# %% [raw]
# DTSMC, bir grafik ve tabu listesi kullanarak maksimum klik boyutunu bulmaya çalışır.
# Algoritma, her düğümü bir kez ziyaret ederek başlar ve her ziyaret ettiği düğümü tabu listesine ekler.
# Her ziyaret ettiği düğümün komşularından biri de ziyaret edilmemişse, o düğümü ziyaret eder ve tabu listesine ekler.
# Bu işlemi tüm düğümler için tekrarlar ve bittiğinde tabu listesinde bulunan düğümlerin oluşturduğu klik boyutunu döndürür.

# %%
class Graph:
    def __init__(self, num_nodes, edges):
        self.num_nodes = num_nodes
        self.edges = edges
        self.adj_list = self._build_adj_list()
        
    def _build_adj_list(self):
        adj_list = {i: [] for i in range(self.num_nodes)}
        for edge in self.edges:
            adj_list[edge[0]].append(edge[1])
            adj_list[edge[1]].append(edge[0])
        return adj_list
    
    def neighbors(self, node):
        return self.adj_list[node]
    
    def degree(self, node):
        return len(self.adj_list[node])



def dtsmc(graph, tabu_list):
    max_clique_size = 0
    for node in range(graph.num_nodes):
        if node in tabu_list:
            continue
        
        tabu_list.append(node)
        for neighbor in graph.neighbors(node):
            if neighbor not in tabu_list:
                dtsmc(graph, tabu_list)
        max_clique_size = max(max_clique_size, len(tabu_list))
        tabu_list.pop()
    return max_clique_size

# %% [markdown]
# İsa KULAKSIZ - 20140201052

# %% [raw]
# DTSMC (Distributed Time Slot Multiple Access) algoritması, bir mobil kablosuz ağda birden çok düğümün zaman dilimleri üzerinden erişimini sağlar.
# Bu algoritma, maksimum iletişim gecikmesi ve maksimum enerji tüketimini hesaplamak için aşağıdaki adımları izleyebilir:
#
# 1 - Düğümlerin zaman dilimlerini belirleyin ve her bir düğüm için bir iletişim süresi oluştur.
# 2 - Her düğüm için, belirlenen iletişim süresi boyunca iletişim gecikmesini hesaplayın. Bu, iletişim süresinin başlangıcından iletişimin tamamlanmasına kadar geçen süreyi ifade eder.
# 3 - Her düğüm için, iletişim süresi boyunca enerji tüketimini hesaplayın. Bu, iletişim süresi boyunca düğümün harcadığı enerjiyi ifade eder.
# 4 - Maksimum iletişim gecikmesini ve maksimum enerji tüketimini bulmak için, tüm düğümlerin iletişim gecikmesi ve enerji tüketim değerlerini karşılaştır

# %% [raw]
# def calculate_performance(clique):
#   max_delay = 0
#   max_energy = 0
#   # Maksimum iletişim gecikmesi ve maksimum enerji tüketimini hesaplayan
#   # kodu buraya yazın.
#   # Örneğin, aşağıdaki gibi bir yapı kullanarak hesaplamaları yapabilirsiniz:
#   for node1 in clique:
#     for node2 in clique:
#       if node1 != node2:
#         # İki düğüm arasındaki iletişim gecikmesini hesaplayın ve
#         # max_delay değişkenine atayın.
#         delay = calculate_delay(node1, node2)
#         max_delay = max(max_delay, delay)
#
#         # İki düğüm arasındaki enerji tüketimini hesaplayın ve
#         # max_energy değişkenine atayın.
#         energy = calculate_energy(node1, node2)
#         max_energy = max(max_energy, energy)
#
#   return max_delay, max_energy
#
# # Maksimum iletişim gecikmesi ve maksimum enerji tüketimini hesaplamak için
# # calculate_performance() metodunu çağırın.
# clique = [node1, node2, node3, ...]
# max_delay, max_energy = calculate_performance(clique)

# %%
# Düğüm sınıfını tanımlayın
class Node:
  def __init__(self, coord):
    # Düğümün koordinatlarını saklayın
    self.coord = coord

# Düğümleri tanımlayın
node1 = Node(coord=(0, 0))
node2 = Node(coord=(1, 0))
node3 = Node(coord=(1, 1))

# Düğümleri bir düğüm grubuna ekleyin
clique = [node1, node2, node3]

# %%
def assign_time_slots(clique):
  # Zaman dilimlerini tutacak bir dizi oluşturun
  time_slots = []
  
  # Düğümleri dolaşarak zaman dilimlerini belirleyin
  for node in clique:
    # Düğümün zaman dilimini belirleyin ve diziye ekleyin
    time_slot = calculate_time_slot(node)
    time_slots.append(time_slot)
  
  # Zaman dilimlerini geri döndürün
  return time_slots

# %%
def calculate_time_slot(node):
  # Düğümün koordinatlarını kullanarak bir zaman dilimi hesaplayın
  time_slot = node.coord[0] * node.coord[1]
  
  # Zaman dilimini geri döndürün
  return time_slot

# %%
def create_communication_times(clique, time_slots):
  # İletişim sürelerini tutacak bir dizi oluşturun
  communication_times = []
  
  # Düğümleri dolaşarak iletişim sürelerini hesaplayın
  for node, time_slot in zip(clique, time_slots):
    # Düğümün iletişim süresini hesaplayın ve diziye ekleyin
    communication_time = calculate_communication_time(node, time_slot)
    communication_times.append(communication_time)
  
  # İletişim sürelerini geri döndürün
  return communication_times

# %%
def calculate_communication_time(node, time_slot):
  # Düğümün koordinatlarını kullanarak iletişim süresini hesaplayın
  communication_time = node.coord[0] + node.coord[1] + time_slot
  
  # İletişim süresini geri döndürün
  return communication_time

# %%
def calculate_delay(node1, node2):
  # Düğümlerin koordinatlarını kullanarak iletişim gecikmesini hesaplayın
  delay = abs(node1.coord[0] - node2.coord[0]) + abs(node1.coord[1] - node2.coord[1])
  
  # İletişim gecikmesini geri döndürün
  return delay

# %%
def create_communication_time(node, time_slot):
  # Düğümün iletişim süresini hesaplayın
  communication_time = ...
  return communication_time

# %% [raw]
# class Node:
#   def __init__(self, coord, id):
#     # Düğümün koordinatlarını saklayın
#     self.coord = coord
#     self.id = id
#
#   def __call__(self):
#     # Düğümleri sıralayarak bir diziye atayın
#     nodes = sorted(clique, key=lambda node: node.id)
#     # Düğümlerin zaman dilimlerini belirleyin
#     time_slots = functions.assign_time_slots(clique)
#
#     # Her bir düğüm için iletişim süresi oluşturun
#     communication_times = functions.create_communication_times(clique, time_slots)
#
#     for node in nodes:
#       # İletişim süresi boyunca iletişim gecikmesini hesaplayın
#       delay = functions.calculate_delay(node, communication_times[node.id])
#       max_delay = max(max_delay, delay)
#
#       # İletişim süresi boyunca enerji tüketimini hesaplayın
#       energy = functions.calculate_energy(node, communication_times[node.id])
#       max_energy = max(max_energy, energy)
#
#     # Maksimum iletişim gecikmesi ve enerji tüketimini geri döndürün
#     print(max_delay)
#     print(max_energy)
#     return max_delay, max_energy
#
# # Düğümleri tanımlayın
# node1 = Node(coord=(0, 0), id=1)
# node2 = Node(coord=(1, 0), id=2)
# node3 = Node(coord=(1, 1), id=3)
#
# # Düğümleri bir düğüm grubuna ekleyin
# clique = [node1, node2, node3]

# %%
class Node:
  def __init__(self, coord, id):
    # Düğümün koordinatlarını saklayın
    self.coord = coord
    self.id = id

  def __call__(self):
    # Düğümleri sıralayarak bir diziye atayın
    nodes = sorted(clique, key=lambda node: node.id)
    # Düğümlerin zaman dilimlerini belirleyin
    time_slots = assign_time_slots(clique)

    # Her bir düğüm için iletişim süresi oluşturun
    communication_times = create_communication_times(clique, time_slots)

    for node in nodes:
      # İletişim süresi boyunca iletişim gecikmesini hesaplayın
      delay = calculate_delay(node, communication_times[node.id])
      max_delay = max(max_delay, delay)

      # İletişim süresi boyunca enerji tüketimini hesaplayın
      energy = calculate_energy(node, communication_times[node.id])
      max_energy = max(max_energy, energy)

    # Maksimum iletişim gecikmesi ve enerji tüketimini geri döndürün
    print(max_delay)
    print(max_energy)
    return max_delay, max_energy

# Düğümleri tanımlayın
node1 = Node(coord=(0, 0), id=1)
node2 = Node(coord=(1, 0), id=2)
node3 = Node(coord=(1, 1), id=3)

# Düğümleri bir düğüm grubuna ekleyin
clique = [node1, node2, node3]

# %%
# Düğümleri tanımlayın
node1 = Node(coord=(0, 0), id=1)
node2 = Node(coord=(1, 0), id=2)
node3 = Node(coord=(1, 1), id=3)

# Düğümleri bir düğüm grubuna ekleyin
clique = [node1, node2, node3]
# Düğüm grubunu çağırarak maksimum iletişim gecikmesini ve enerji tüketimini hesaplayın
max_delay, max_energy = clique[0]()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [181], in <cell line: 9>()
#       7 clique = [node1, node2, node3]
#       8 # Düğüm grubunu çağırarak maksimum iletişim gecikmesini ve enerji tüketimini hesaplayın
# ----> 9 max_delay, max_energy = clique[0]()
#
# Input In [180], in Node.__call__(self)
#      14 communication_times = create_communication_times(clique, time_slots)
#      16 for node in nodes:
#      17   # İletişim süresi boyunca iletişim gecikmesini hesaplayın
# ---> 18   delay = calculate_delay(node, communication_times[node.id])
#      19   max_delay = max(max_delay, delay)
#      21   # İletişim süresi boyunca enerji tüketimini hesaplayın
#
# Input In [171], in calculate_delay(node1, node2)
#       1 def calculate_delay(node1, node2):
#       2   # Düğümlerin koordinatlarını kullanarak iletişim gecikmesini hesaplayın
# ...
